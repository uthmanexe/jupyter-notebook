# %% [markdown]
# # 1-7.2 Intro Python Practice
# ## `while()` loops & increments
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - create forever loops using `while` and `break`
# - use incrementing variables in a while loop
# - control while loops using Boolean operators

# %%
# [ ] use a "forever" while loop to get user input of integers to add to sum, 
# until a non-digit is entered, then break the loop and print sum
sum = 0
while True:
    user_input = input(
        "Enter an integer to add to the sum (or a non-digit to stop): ").strip()

    if user_input.isdigit():
        sum += int(user_input)
    else:
        break

print(f"The final sum is: {sum}")
# Out:
# The final sum is: 6

# %%
# [ ] use a while True loop (forever loop) to give 4 chances for input of a correct color in a rainbow
# rainbow = "red orange yellow green blue indigo violet"

rainbow = "red orange yellow green blue indigo violet"
chances = 4

while True:
    if chances == 0:
        print("Out of chances!")
        break

    guess = input("Guess a color in the rainbow: ").strip().lower()

    if guess in rainbow.split():
        print("Correct!")
        break
    else:
        chances -= 1
        print(f"Incorrect. Remaining chances: {chances}")
# Out:
# Correct!

# %%
# [ ] Get input for a book title, keep looping while input is Not in title format (title is every word capitalized)
title = ""

title = ""

while True:
    title = input("Enter a book title (every word capitalized): ").strip()

    if title.istitle():
        break
    else:
        print("That is not in title format. Please try again.")

print(f"Thank you. Book title saved: {title}")
# Out:
# That is not in title format. Please try again.
# That is not in title format. Please try again.
# Thank you. Book title saved: Lord Of The Rings

# %%
# [ ] create a math quiz question and ask for the solution until the input is correct

correct_answer = 42

while True:
    user_input = input("What is 6 multiplied by 7? ").strip()

    if user_input.isdigit() and int(user_input) == correct_answer:
        print("Correct! Excellent job.")
        break
    else:
        print("Incorrect answer. Please try again.")
# Out:
# Correct! Excellent job.

# %% [markdown]
# ### Fix the Error

# %%
# [ ] review the code, run, fix the error
tickets = int(input("enter tickets remaining (0 to quit): "))

while tickets > 0:
        # if tickets are multiple of 3 then "winner"
    if int(tickets/3) == tickets/3:
        print("you win!")
    else:
        print("sorry, not a winner.")
    tickets = int(input("enter tickets remaining (0 to quit): "))

print("Game ended")
# Out:
# sorry, not a winner.
# you win!
# Game ended

# %% [markdown]
# ### create a function: quiz_item()  that asks a question and tests if input is correct
# - quiz_item()has 2 parameter **strings**: question and solution
# - shows question, gets answer input
# - returns True if `answer == solution` or continues to ask question until correct answer is provided
# - use a while loop
#
# create 2 or more quiz questions that call quiz_item()
# **Hint**: provide multiple choice or T/F answers

# %%
# Create quiz_item() and 2 or more quiz questions that call quiz_item()

def quiz_item(question, solution):
    while True:
        answer = input(question).strip().lower()
        if answer == solution.strip().lower():
            print("Correct!\n")
            return True
        else:
            print("Incorrect. Please try again.\n")


q1 = "What is the capital of France?\nA) Berlin\nB) Paris\nC) Madrid\nYour answer (A/B/C): "
sol1 = "B"

q2 = "True or False: Python is a compiled language. "
sol2 = "False"

print("--- Start of Quiz ---\n")
quiz_item(q1, sol1)
quiz_item(q2, sol2)
print("--- Quiz Completed! ---")
# Out:
# --- Start of Quiz ---
#
# Incorrect. Please try again.
#
# Correct!
#
# Correct!
#
# --- Quiz Completed! ---

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
